# %%
temp = []
with open('lena_p1.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = [i for i in range(256)]
plt.figure()
plt.bar(x,temp, width=1)
plt.xlim(0, 255)
plt.title('Histogram of Lena (part1)')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('baboon_p1.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = [i for i in range(256)]
plt.figure()
plt.bar(x,temp, width=1)
plt.xlim(0, 255)
plt.title('Histogram of baboon (part1)')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('lenaerrdiff_p2.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = [i for i in range(len(temp))]
plt.figure()
plt.bar(x,temp, width=1)
plt.xlim(0, len(temp))
plt.title('Histogram of lenaerrdiff (part2)')
plt.xlabel('Run Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('weaskedforit_p2.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = [i for i in range(len(temp))]
plt.figure()
plt.bar(x,temp, width=100)
plt.xlim(0, len(temp))
plt.title('Histogram of weaskedforit (part2)')
plt.xlabel('Run Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('lena_bit0_p3.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = [i for i in range(len(temp))]
plt.figure()
plt.bar(x,temp, width = 0.8)
plt.xlim(0, len(temp))
plt.title('Histogram of lena_bit0 (part3)')
plt.xlabel('Run Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('lena_bit1_p3.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = [i for i in range(len(temp))]
plt.figure()
plt.bar(x,temp, width = 0.8)
plt.xlim(0, len(temp))
plt.title('Histogram of lena_bit1 (part3)')
plt.xlabel('Run Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('lena_bit2_p3.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = [i for i in range(len(temp))]
plt.figure()
plt.bar(x,temp, width = 0.8)
plt.xlim(0, len(temp))
plt.title('Histogram of lena_bit2 (part3)')
plt.xlabel('Run Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('lena_bit3_p3.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = [i for i in range(len(temp))]
plt.figure()
plt.bar(x,temp, width = 0.8)
plt.xlim(0, len(temp))
plt.title('Histogram of lena_bit3 (part3)')
plt.xlabel('Run Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('lena_bit4_p3.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = [i for i in range(len(temp))]
plt.figure()
plt.bar(x,temp, width = 0.8)
plt.xlim(0, len(temp))
plt.title('Histogram of lena_bit4 (part3)')
plt.xlabel('Run Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('lena_bit5_p3.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = [i for i in range(len(temp))]
plt.figure()
plt.bar(x,temp, width = 1)
plt.xlim(0, len(temp))
plt.title('Histogram of lena_bit5 (part3)')
plt.xlabel('Run Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('lena_bit6_p3.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = [i for i in range(len(temp))]
plt.figure()
plt.bar(x,temp, width = 1)
plt.xlim(0, len(temp))
plt.title('Histogram of lena_bit6 (part3)')
plt.xlabel('Run Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('lena_bit7_p3.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = [i for i in range(len(temp))]
plt.figure()
plt.bar(x,temp, width = 1)
plt.xlim(0, len(temp))
plt.title('Histogram of lena_bit7 (part3)')
plt.xlabel('Run Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('lena_p4.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = list(range(-255, 256))
plt.figure()
plt.bar(x,temp, width = 1)
#plt.xlim(, len(temp))
plt.title('Histogram of lena (part4)')
plt.xlabel('Difference Pixel Values')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
temp = []
with open('baboon_p4.txt') as f:
    cur = f.readlines()
    for num in cur:
        temp.append(int(num[:-1]))
x = list(range(-255, 256))
plt.figure()
plt.bar(x,temp, width = 1)
#plt.xlim(, len(temp))
plt.title('Histogram of baboon (part4)')
plt.xlabel('Difference Pixel Values')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
